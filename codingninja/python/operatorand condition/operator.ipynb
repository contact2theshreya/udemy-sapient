# %%
product_name = "iphone"

print(product_name)

price = 1000
discount = 200

price -= discount

print(price)

marks = 300
grace = 5

marks += grace

print(marks)

x = 10

x **= 2 # x = x ** 2 

print(x)
# Out:
# iphone
# 800
# 305
# 100

# %%
y = 5

y += 3
print(y)

y //= 2
print(y)

print(y)

print(y < 5)

print(y > 5)

print(y == 5)

x = 4

print(y == x) # check if y is equals to x

print(y != 6)
# Out:
# 8
# 4
# 4
# True
# False
# False
# True
# True

# %%
# Logical operators

print(False and False)
print(False and True)
print(True and False)
print(True and True)

print(False or False)
print(False or True)
print(True or False)
print(True or True)

print(not True)

print(not False)

is_logged_in = True

is_address_available = True

name_of_customer = "Sanket"

address_of_customer = "A/D 105, Delhi"

print((is_logged_in == True) and (is_address_available == True) and (name_of_customer == "Sanket"))
# Out:
# False
# False
# False
# True
# False
# True
# True
# True
# False
# True
# True

# %%
print(5 and 3) # will check both side and if both is truthy will return last true value

print(5 or 3) # will check either side till it found truthy value so it will return 5 instantly

print(0 and 5) # will return 0 coz fist operand is false so it wont check 5

print(5 & 3) # will do and on bits and will return decimal value

print(5 | 3)# will do or  on bits and will return decimal value

print(5 ^ 3) 

print(5 >> 1) # will ryt shift bits of 5 by 1 place and will fill remaining place with 0 and will return decimal valuye

print(2 << 2) # will left  shift bits of 2 by 2 place and will fill remaining place with 0 and will return decimal valuye
# Out:
# 3
# 5
# 0
# 1
# 7
# 6
# 2
# 8

# %%
print(0 | 5) # will return last truthy value 5 as it will check both
# Out:
# 5
