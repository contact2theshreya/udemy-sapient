# %%
print("hello world") # here print is a blackbox inbuilt function where we gave input hello world
# Out:
# hello world

# %%
print('hello')
# Out:
# hello

# %%
print("you'r")
# Out:
# you'r

# %%
print("I'm learning Python.\nPython is a high-level language.") ## print multiple lines
# Out:
# I'm learning Python.
# Python is a high-level language.
