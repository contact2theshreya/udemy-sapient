# %%
import array
numbers = array.array('i',[2,3,4])
print(numbers)
numbers.append(10)
print(numbers)
# Out:
# array('i', [2, 3, 4])
# array('i', [2, 3, 4, 10])

# %%
print(f"First element:{numbers[0]}")
# Out:
# First element:2

# %%
numbers.pop(1)
print(numbers)
# Out:
# array('i', [2, 4, 10])

# %%
for num in numbers:
    print(num)
# Out:
# 2
# 4
# 10

# %%
percentages = array.array('d',[90.12,1.23])
for num in percentages:
    print(num)
# Out:
# 90.12
# 1.23

# %%
# Dynamic list

# %%
numbers=[1,2,3,4]
print(type(numbers))
# Out:
# <class 'list'>

# %%
# convert arr(any iterable) to list
import array as array
arr = array.array('i',[1,2])
mylist = list(arr)
print(type(mylist))
# Out:
# <class 'list'>

# %%
mylist.append(4)
mylist.append("sohan")
print(mylist[-1])
#0th index - ist element,-1 = last index,pop
# Out:
# sohan

# %%
# Add numbers
marks = [0,1,2]
tot = 0
for num in marks:
    tot += num
print(tot)
# 2nd way 
tot2 =0
for i in range(len(marks)):
    tot2 += marks[i]
print(tot2)
# Out:
# 3
# 3

# %%
# list operation
nums=[1,2]
nums.append(3)
print(nums)
nums.insert(1,5)
print(nums)
nums.extend([10,13,12])
print(nums)
# Out:
# [1, 2, 3]
# [1, 5, 2, 3]
# [1, 5, 2, 3, 10, 13, 12]

# %%
nums=[2,1,3,4,1,5,6,2]
nums.remove(1)
print(nums)
# Out:
# [2, 3, 4, 1, 5, 6, 2]

# %%
nums=[2,1,3,4,1,5,6,2]
nums.clear()
print(nums)
# Out:
# []

# %%
nums =[1,2,3,4]
nums2=nums.copy()
nums2.pop()
print(nums2)
print(nums)
# Out:
# [1, 2, 3]
# [1, 2, 3, 4]

# %%
nums=[2,1,3,2,1]
print(nums.index(3))
# Out:
# 2

# %%
nums=[1,2,3,4,5]
nums.reverse()
print(nums)
# Out:
# [5, 4, 3, 2, 1]

# %%
nums=[2,4,3,1,5,2,6,2,1]
nums.sort()
print(nums)
# Out:
# [1, 1, 2, 2, 2, 3, 4, 5, 6]

# %%
nums=[1,2]
nums2=[3,4]
print(nums+3*nums2)
# Out:
# [1, 2, 3, 4, 3, 4, 3, 4]
