# %%
all_marks = list(map(int,input().split(" ")))
# 👉 split() → breaks string into parts
# 👉 map(int, ...) → converts each part to int
# 👉 list() → converts to list
# Out:
#  1 5 3 2

# %%
max_marks = 0
for m in all_marks:
    max_marks=max(max_marks,m)
print(max_marks)
# Out:
# 5
