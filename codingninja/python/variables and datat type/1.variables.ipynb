# %%
age=10

# %%
name="shreya"

# %%
print(name,age)
# Out:
# shreya 10

# %%
x,y,z = 4,50.6,"something"

# %%
print(x,y,z)
# Out:
# 4 50.6 something

# %%
a,b,c=10,20
print(c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 a,b,c=10,20
#       2 print(c)
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
age,AGE,Age = 1,2,3
print(age,AGE,Age)
# Out:
# 1 2 3

# %%
for = 10
# Out:
#   Cell In[20], line 1
#     for = 10
#         ^
# SyntaxError: invalid syntax

# %%
is_product_available = True
print(is_product)
# Out:
# True

# %%
complex_number = 3+8j #complex no store it is a diff data type
print(complex_number,type(complex_number))
# Out:
# (3+8j) <class 'complex'>

# %%
x = "abcd"
x = 10

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
print("collecting user input")
user_pno = input()
print("pno",user_pno)
# Out:
# collecting user input
#  23
# pno 23

# %%
print(type(user_pno)) # string but if we want some mathematic operation then we need to do type conversion
print(type(int(user_pno))) # type conversion
# Out:
# <class 'str'>
# <class 'int'>

# %%
x = float("20")
print(x,type(x))
# Out:
# 20.0 <class 'float'>

# %%
print(float("20sanket"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(float("20sanket"))
#
# ValueError: could not convert string to float: '20sanket'
